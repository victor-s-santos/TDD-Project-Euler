# %% [markdown]
# * # Names scores

# %% [markdown]
# Using names.txt (right click and 'Save Link/Target As...'), a 46K text file containing over five-thousand first names, begin by sorting it into alphabetical order. Then working out the alphabetical value for each name, multiply this value by its alphabetical position in the list to obtain a name score.
#
# For example, when the list is sorted into alphabetical order, COLIN, which is worth 3 + 15 + 12 + 9 + 14 = 53, is the 938th name in the list. So, COLIN would obtain a score of 938 × 53 = 49714.
#
# What is the total of all the name scores in the file?

# %% [markdown]
# ### First, I must to break this problem into many small pieces as much as I can.

# %% [markdown]
# * 1 open the file,
# * 2 read the file,
# * 3 sorte the names into alphabetical order,
# * 4 setting for each letter a numeric value, according to its position,
# * 5 loocking for the score for each number,
# * 6 loocking for the sum of these score.

# %%
if __name__ == '__main__':
    assert contagem(file) > 5000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ee80fdd1e2e2> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     assert contagem(file) > 5000
#
# <ipython-input-7-a875e38efedc> in contagem(file)
#       1 def contagem(file):
# ----> 2     with open(file) as f:
#       3         read_file = f.read()
#       4
#       5 if __name__ == '__main__':
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
def contagem(file):
    with open(file) as f:
        read_file = f.read()

if __name__ == '__main__':
    assert int(contagem('external_files/p022_names.txt')) > 5000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-764d9a8a374c> in <module>()
#       4
#       5 if __name__ == '__main__':
# ----> 6     assert int(contagem('external_files/p022_names.txt')) > 5000
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
def contagem(file):
    with open(file) as f:
        read_file = f.read()
        return(read_file.count(','))

if __name__ == '__main__':
    assert int(contagem('external_files/p022_names.txt')) > 5000
"""Because I know my external_file has more than 5000 names."""

# %%
def contagem(file):
    with open(file) as f:
        read_file = f.readlines()
        #read_file = list(read_file)
        #ordenado = read_file2.sort()
        return(len(read_file))

# %%
contagem('external_files/p022_names.txt')
# Out:
# 1

# %%
def contagem(file):
    lista = []
    with open(file) as f:
        read_file = f.readline()
        #read_file = list(read_file)
        #ordenado = read_file2.sort()
        for each_word in read_file:
            lista.append(each_word)
        return(lista)

# %%
contagem('external_files/p022_names.txt')

# %%
def contagem(file):
    lista = []
    with open(file) as f:
        read_file = f.readlines()
        #read_file = list(read_file)
        #ordenado = read_file2.sort()
        for each_word in read_file:
            each_word = each_word.strip("""""")
            lista.append(each_word)
        return(lista)

# %%
"""Pegando um trecho do arquivo"""
string = "MARY","PATRICIA","LINDA","BARBARA","ELIZABETH","JENNIFER","MARIA","SUSAN","MARGARET"

# %%
"""Jogar tudo nume lista:"""
lista = []
for palavra in string:
    lista.append(palavra)

# %%
print(lista[0])
# Out:
# MARY

# %%
print(lista)
# Out:
# ['MARY', 'PATRICIA', 'LINDA', 'BARBARA', 'ELIZABETH', 'JENNIFER', 'MARIA', 'SUSAN', 'MARGARET']

# %%
"""Ordenar em ordem alfabética os nomes na lista"""
for x in range(len(lista)):
    for y in range(len(lista)):
        if lista[x] < lista[y]:
            lista[x], lista[y] = lista[y], lista[x]
print(lista)
# Out:
# ['BARBARA', 'ELIZABETH', 'JENNIFER', 'LINDA', 'MARGARET', 'MARIA', 'MARY', 'PATRICIA', 'SUSAN']

# %%
print(lista)
# Out:
# ['BARBARA', 'ELIZABETH', 'JENNIFER', 'LINDA', 'MARGARET', 'MARIA', 'MARY', 'PATRICIA', 'SUSAN']

# %%
lista = []
with open('external_files/p022_names.txt') as file:
    read_file = file.readlines()
    print(type(read_file))
print(read_file[1])
"""In this way, I am creating a list with only one element."""
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-db8be7c18bb4> in <module>()
#       3     read_file = file.readlines()
#       4     print(type(read_file))
# ----> 5 print(read_file[1])
#
# IndexError: list index out of range

# %%
lista = []
with open('external_files/p022_names.txt') as file:
    read_file = file.readlines()
    read_file = read_file.strip().split(',')
    print(type(read_file))
print(read_file[1])
"""I may not to make a list"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-090af4a8ce1d> in <module>()
#       2 with open('external_files/p022_names.txt') as file:
#       3     read_file = file.readlines()
# ----> 4     read_file = read_file.strip().split(',')
#       5     print(type(read_file))
#       6 print(read_file[1])
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
lista = []
with open('external_files/p022_names.txt') as file:
    read_file = file.readline()
    read_file = read_file.strip().split(',')
    print(type(read_file))
print(read_file[1])
# Out:
# <class 'list'>
# "PATRICIA"

# %%
i = 0
while i < 10:
    print(read_file[i])
    i += 1
"""Now I can select any name by the itself index"""
# Out:
# "MARY"
# "PATRICIA"
# "LINDA"
# "BARBARA"
# "ELIZABETH"
# "JENNIFER"
# "MARIA"
# "SUSAN"
# "MARGARET"
# "DOROTHY"

# %%
for x in range(len(read_file)):
    for y in range(len(read_file)):
        if read_file[x] < read_file[y]:
            read_file[x], read_file[y] = read_file[y], read_file[x]
print(read_file)
# Out:
# ['"AARON"', '"ABBEY"', '"ABBIE"', '"ABBY"', '"ABDUL"', '"ABE"', '"ABEL"', '"ABIGAIL"', '"ABRAHAM"', '"ABRAM"', '"ADA"', '"ADAH"', '"ADALBERTO"', '"ADALINE"', '"ADAM"', '"ADAN"', '"ADDIE"', '"ADELA"', '"ADELAIDA"', '"ADELAIDE"', '"ADELE"', '"ADELIA"', '"ADELINA"', '"ADELINE"', '"ADELL"', '"ADELLA"', '"ADELLE"', '"ADENA"', '"ADINA"', '"ADOLFO"', '"ADOLPH"', '"ADRIA"', '"ADRIAN"', '"ADRIANA"', '"ADRIANE"', '"ADRIANNA"', '"ADRIANNE"', '"ADRIEN"', '"ADRIENE"', '"ADRIENNE"', '"AFTON"', '"AGATHA"', '"AGNES"', '"AGNUS"', '"AGRIPINA"', '"AGUEDA"', '"AGUSTIN"', '"AGUSTINA"', '"AHMAD"', '"AHMED"', '"AI"', '"AIDA"', '"AIDE"', '"AIKO"', '"AILEEN"', '"AILENE"', '"AIMEE"', '"AISHA"', '"AJA"', '"AKIKO"', '"AKILAH"', '"AL"', '"ALAINA"', '"ALAINE"', '"ALAN"', '"ALANA"', '"ALANE"', '"ALANNA"', '"ALAYNA"', '"ALBA"', '"ALBERT"', '"ALBERTA"', '"ALBERTHA"', '"ALBERTINA"', '"ALBERTINE"', '"ALBERTO"', '"ALBINA"', '"ALDA"', '"ALDEN"', '"ALDO"', '"ALEASE"', '"ALEC"', '"ALECIA"', '"ALEEN"', '"ALEIDA"', '"ALEISH
# ...

# %%
print(len(read_file))
# Out:
# 5163

# %%
"""I make it a function"""
def alphabetic_list(where):
    with open(where) as file:
        """Open and process my data"""
        read_file = file.readline()
        read_file = read_file.strip().split(',')
        """--#--"""
        
        """Sets to alphabetical order""" 
        for x in range(len(read_file)):
            for y in range(len(read_file)):
                if read_file[x] < read_file[y]:
                    read_file[x], read_file[y] = read_file[y], read_file[x]
        return(read_file[0])

# %%
alphabetic_list('external_files/p022_names.txt')
# Out:
# '"AARON"'

# %%
"""I make it a function"""
def alphabetic_list(where):
    with open(where) as file:
        """Open and process my data"""
        read_file = file.readline()
        read_file = read_file.strip().split(',')
        """--#--"""
        
        """Sets to alphabetical order""" 
        for x in range(len(read_file)):
            for y in range(len(read_file)):
                if read_file[x] < read_file[y]:
                    read_file[x], read_file[y] = read_file[y], read_file[x]
                    return read_file

def set_number(where):
    for word in range(len(alphabetic_list(where))):
        for letter in range(len(alphabetic_list(where))):
            if letter == 'A':
                letter = 1
            elif letter == 'E':
                letter = 2
            elif letter == 'I':
                letter = 3
            elif letter == 'O':
                letter = 4
            elif letter == 'U':
                letter = 5
    return(letter)

# %%
set_number('external_files/p022_names.txt')
# Out:
# 5162

# %%
def alphabetic_list(where):
    with open(where) as file:
        """Open and process my data"""
        read_file = file.readline()
        read_file = read_file.strip().split(',')
        for palavras in (read_file):
            print(palavras)

# %%
alphabetic_list('external_files/p022_names.txt')
# Out:
# "MARY"
# "PATRICIA"
# "LINDA"
# "BARBARA"
# "ELIZABETH"
# "JENNIFER"
# "MARIA"
# "SUSAN"
# "MARGARET"
# "DOROTHY"
# "LISA"
# "NANCY"
# "KAREN"
# "BETTY"
# "HELEN"
# "SANDRA"
# "DONNA"
# "CAROL"
# "RUTH"
# "SHARON"
# "MICHELLE"
# "LAURA"
# "SARAH"
# "KIMBERLY"
# "DEBORAH"
# "JESSICA"
# "SHIRLEY"
# "CYNTHIA"
# "ANGELA"
# "MELISSA"
# "BRENDA"
# "AMY"
# "ANNA"
# "REBECCA"
# "VIRGINIA"
# "KATHLEEN"
# "PAMELA"
# "MARTHA"
# "DEBRA"
# "AMANDA"
# "STEPHANIE"
# "CAROLYN"
# "CHRISTINE"
# "MARIE"
# "JANET"
# "CATHERINE"
# "FRANCES"
# "ANN"
# "JOYCE"
# "DIANE"
# "ALICE"
# "JULIE"
# "HEATHER"
# "TERESA"
# "DORIS"
# "GLORIA"
# "EVELYN"
# "JEAN"
# "CHERYL"
# "MILDRED"
# "KATHERINE"
# "JOAN"
# "ASHLEY"
# "JUDITH"
# "ROSE"
# "JANICE"
# "KELLY"
# "NICOLE"
# "JUDY"
# "CHRISTINA"
# "KATHY"
# "THERESA"
# "BEVERLY"
# "DENISE"
# "TAMMY"
# "IRENE"
# "JANE"
# "LORI"
# "RACHEL"
# "MARILYN"
# "ANDREA"
# "KATHRYN"
# "LOUISE"
# "SARA"
# "ANNE"
# "JACQUELINE"
# "WANDA"
# "BONNIE"
# "JULIA"
# "RUBY"
# "LOIS"
# ...

# %%
"""A good idea to set for each letter a value, is to use a dictionary:"""
d = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4,
     'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 
     'K':10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 
    'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 
    'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24,
    'Z': 25}

# %%
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25}

# %%
"""Now, I must to make this functions returning values that I can take by index"""
def alphabetic_list(where):
    with open(where) as file:
        """Open and process my data"""
        dados = file.readline()
        read_file = dados.strip().split(',')
        return(read_file[0:5])
    
if __name__ == '__main__':
    assert type(alphabetic_list('external_files/p022_names.txt')) == list

# %%
alphabetic_list('external_files/p022_names.txt')
# Out:
# ['"MARY"', '"PATRICIA"', '"LINDA"', '"BARBARA"', '"ELIZABETH"']

# %%
Now I can compare each letter-name in the list with each number in the dictionary

# %%
a = alphabetic_list('external_files/p022_names.txt')
for palavra in a:
    print(palavra)
    for letra in palavra:
        print(letra)
# Out:
# "MARY"
# "
# M
# A
# R
# Y
# "
# "PATRICIA"
# "
# P
# A
# T
# R
# I
# C
# I
# A
# "
# "LINDA"
# "
# L
# I
# N
# D
# A
# "
# "BARBARA"
# "
# B
# A
# R
# B
# A
# R
# A
# "
# "ELIZABETH"
# "
# E
# L
# I
# Z
# A
# B
# E
# T
# H
# "
