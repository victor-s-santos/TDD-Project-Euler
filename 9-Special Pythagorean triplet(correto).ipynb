# %% [markdown]
# * # Problem 9 - Special Pythagorean triplet
# A Pythagorean triplet is a set of three natural numbers, a < b < c, for which,
# a² + b² = c²
#
# For example, 3² + 4² = 9 + 16 = 25 = 5².
# There exists exactly one Pythagorean triplet for which a + b + c = 1000.
# Find the product abc.

# %% [markdown]
# Pythagorean numbers:
# * ### a	b	c
# * 3	4	5
# * 5	12	13
# * 7	24	25
# * 9	40	41
# * 11	60	61
# * 13	84	85
# * 15	112	113
# * 17	144	145
# * 19	180	181
# * 21	220	221
# * 23	264	265
# * 25	312	313
# * 27	364	365
# * 29	420	421
# * 31	480	481
# But, if I look for these numbers, I am seeing that is impossible to get a triplet which a + b + c = 1000. So, I must to leave this pattern.

# %% [markdown]
# #### Dividing the problem in many parts, I imagine the first one is to check this sum(a + b + c)

# %%
def check(a, b, c):
    if a + b + c == 1000:
        return True
    else:
        return False
if __name__ == '__main__':
    assert check(1000, 0, 0) == True
    assert check(900, 50, 50) == True
    assert check(333, 333, 334) == True
    assert check(0,0,0) == False
    assert check(1000.0, 0.0, 0.0) == True
    assert check(-100, 80, 9) == False

# %% [markdown]
# ### Now, I am using the Euclid's Formula to get a pythagorean triplet.
# * a = (m²) - (n²)
#
# * b = 2mn
#
# * c = (m²) + (n²)
#
# * m > n > 0

# %%
for i in range(1, 1000):
    for j in range(1, 1000):
        if i > j:
            a = (i ** 2) - (j ** 2)
            b = 2 * i * j
            c = (i ** 2) + (j ** 2)
            if (a + b + c) == 1000:
                print(a,b,c)
        else:
            pass
# Out:
# 375 200 425

# %%
for i in range(1, 1000):
    for j in range(1, 1000):
        if i > j:
            a = (i ** 2) - (j ** 2)
            b = 2 * i * j
            c = (i ** 2) + (j ** 2)
            if (a + b + c) < 100:
                print(a,b,c)
# Out:
# 3 4 5
# 8 6 10
# 5 12 13
# 15 8 17
# 12 16 20
# 7 24 25
# 24 10 26
# 21 20 29
# 16 30 34
# 9 40 41
# 35 12 37
# 32 24 40

# %%
"""a = (m²) - (n²)
b = 2mn
c = (m²) + (n²)
m > n > 0"""
for i in range(1, 100):
    for j in range(1,100):
        a = (i**2) - (j**2)
        b = 2*i*j
        c = (i**2) + (j**2)
        print(a,b,c)
# Out:
# 0 2 2
# -3 4 5
# -8 6 10
# -15 8 17
# -24 10 26
# -35 12 37
# -48 14 50
# -63 16 65
# -80 18 82
# -99 20 101
# -120 22 122
# -143 24 145
# -168 26 170
# -195 28 197
# -224 30 226
# -255 32 257
# -288 34 290
# -323 36 325
# -360 38 362
# -399 40 401
# -440 42 442
# -483 44 485
# -528 46 530
# -575 48 577
# -624 50 626
# -675 52 677
# -728 54 730
# -783 56 785
# -840 58 842
# -899 60 901
# -960 62 962
# -1023 64 1025
# -1088 66 1090
# -1155 68 1157
# -1224 70 1226
# -1295 72 1297
# -1368 74 1370
# -1443 76 1445
# -1520 78 1522
# -1599 80 1601
# -1680 82 1682
# -1763 84 1765
# -1848 86 1850
# -1935 88 1937
# -2024 90 2026
# -2115 92 2117
# -2208 94 2210
# -2303 96 2305
# -2400 98 2402
# -2499 100 2501
# -2600 102 2602
# -2703 104 2705
# -2808 106 2810
# -2915 108 2917
# -3024 110 3026
# -3135 112 3137
# -3248 114 3250
# -3363 116 3365
# -3480 118 3482
# -3599 120 3601
# -3720 122 3722
# -3843 124 3845
# -3968 126 3970
# -4095 128 4097
# -4224 130 4226
# -4355 132 4357
# -4488 134 4490
# ...

# %%
#to avoid the negative value, I must to define i > j
for i in range(1, 100):
    for j in range(1,100):
        if i > j:
            a = (i**2) - (j**2)
            b = 2*i*j
            c = (i**2) + (j**2)
            print(a,b,c)
# Out:
# 3 4 5
# 8 6 10
# 5 12 13
# 15 8 17
# 12 16 20
# 7 24 25
# 24 10 26
# 21 20 29
# 16 30 34
# 9 40 41
# 35 12 37
# 32 24 40
# 27 36 45
# 20 48 52
# 11 60 61
# 48 14 50
# 45 28 53
# 40 42 58
# 33 56 65
# 24 70 74
# 13 84 85
# 63 16 65
# 60 32 68
# 55 48 73
# 48 64 80
# 39 80 89
# 28 96 100
# 15 112 113
# 80 18 82
# 77 36 85
# 72 54 90
# 65 72 97
# 56 90 106
# 45 108 117
# 32 126 130
# 17 144 145
# 99 20 101
# 96 40 104
# 91 60 109
# 84 80 116
# 75 100 125
# 64 120 136
# 51 140 149
# 36 160 164
# 19 180 181
# 120 22 122
# 117 44 125
# 112 66 130
# 105 88 137
# 96 110 146
# 85 132 157
# 72 154 170
# 57 176 185
# 40 198 202
# 21 220 221
# 143 24 145
# 140 48 148
# 135 72 153
# 128 96 160
# 119 120 169
# 108 144 180
# 95 168 193
# 80 192 208
# 63 216 225
# 44 240 244
# 23 264 265
# 168 26 170
# 165 52 173
# 160 78 178
# 153 104 185
# 144 130 194
# 133 156 205
# 120 182 218
# 105 208 233
# 88 234 250
# 69 260 269
# 48 286 290
# 25 312 313
# 195 28 197
# 192 56 200
# 187 84 205
# 180 112 212
# ...

# %%
#and now I am loocking for check the assertion: a + b + c = 1000
for i in range(1, 100):
    for j in range(1,100):
        if i > j:
            a = (i**2) - (j**2)
            b = 2*i*j
            c = (i**2) + (j**2)
            if (a + b + c) == 1000:
                print(a,b,c)
# Out:
# 375 200 425

# %%
#and print the product
for i in range(1, 100):
    for j in range(1,100):
        if i > j:
            a = (i**2) - (j**2)
            b = 2*i*j
            c = (i**2) + (j**2)
            if (a + b + c) == 1000:
                print(a*b*c)
# Out:
# 31875000
